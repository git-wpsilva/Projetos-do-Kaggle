# %% [markdown]
# <a href="https://www.kaggle.com/code/wesleypdasilva/desafio-titanic-random-forest?scriptVersionId=143573997" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # $\large{\color{CadetBlue}{\textbf{Desafio do Titanic com Random Florest 🚢}}}$
# ### De 2224 pessoas, morreram 1502;
# ### No data 'train_data' contém 891 registros;
# ### O dado de teste 'teste_data' possui 418 registros;
#
#  Este exércicio é mais direto ao ponto, se quiser acompanhar uma análise exploratória mais profunda deste caso, veja este [exercício aqui](https://www.kaggle.com/code/wesleypdasilva/desafio-titanic-linear-regression)

# %% [markdown]
# ## $\large{\color{RoyalBlue}{1.}}$ $\large{\color{CadetBlue}{\textbf{Carregando as Bibliotecas 📚}}}$

# %%
import numpy as np 
import pandas as pd 
import os

# %% [markdown]
# ## $\large{\color{RoyalBlue}{2.}}$ $\large{\color{CadetBlue}{\textbf{Lendo os dados 👀}}}$

# %%
train_data = pd.read_csv("/kaggle/input/titanic/train.csv")
train_data.head()

# %%
teste_data = pd.read_csv('/kaggle/input/titanic/test.csv')
teste_data.head()

# %% [markdown]
# ## $\large{\color{RoyalBlue}{3.}}$ $\large{\color{CadetBlue}{\textbf{Análise Exploratória dos Dados 🔎}}}$

# %%
mulher = train_data.loc[train_data.Sex == 'female']["Survived"]
taxa_mulher = sum(mulher)/len(mulher)

print("% de mulheres sobreviventes:", taxa_mulher)
print(sum(mulher), 'total')
print(len(mulher), 'comprimento')

# %%
homem = train_data.loc[train_data.Sex == 'male']["Survived"]
taxa_homem = sum(homem)/len(homem)

print("% de homens sobreviventes:", taxa_homem)

# %% [markdown]
# ## $\large{\color{RoyalBlue}{4.}}$ $\large{\color{CadetBlue}{\textbf{Criação do Modelo 🧠}}}$

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data["Survived"]

features = ["Pclass", "Sex", "SibSp", "Parch"]
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(teste_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': teste_data.PassengerId, 'Survived': predictions})
output.to_csv('submission.csv', index=False)
print("Progresso salvo!")
